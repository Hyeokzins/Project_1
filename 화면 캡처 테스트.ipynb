# %%
from PIL import ImageGrab
from PIL import Image
import IPython.display as display

left = 550
top = 300
right = 650
bottom = 400

image = ImageGrab.grab(bbox=(left, top, right, bottom))
display.display(image)

#screenshot.save("PIL을 이용한추출된이미지.png")
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

image = Image.open('숫자 데이터.png')

display.display(image)

result = pytesseract.image_to_string(image, config='--psm 10 --oem 3 -c tessedit_char_whitelist=0123456789')
print(result)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=43x39>

# %%
from IPython.display import display

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

img = Image.open('numimg.png')
display(img)

text = pytesseract.image_to_string(img, lang='kor+eng')
print(text)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=554x377>
# sdfsadfsadfiklsdjfl
# dskfidslfdslakflsdajf
#
# sadASDFAFDLIkfldskflkdf
# fslkdnflas
#
# 가나다라 문어 오징어 어머니 촬영
# 양 양
#
# a
#
# 때
#
# 12324324
# 32431543531

# %%
from flask import Flask, render_template

app = Flask(__name__)

@app.route('/')
def index():
    result = 42  # 파이썬 코드 실행 결과
    return render_template('index.html', result=result)

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

img2 = Image.open('병원 접수대기 화면.png')
display(img2)

text2 = pytesseract.image_to_string(img2, lang='kor+eng')

print(text2)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=298x169>
# Bees
# Deets
# [000
# Daeg
# Does
# 벼여베가
#
# 창구
# usa
# wane
#
# 대기인수
# 0 =
# o 8
# 38
# 1 8
# 0 그
# 19
#
# 혼잡도

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

img3 = Image.open('대기환자 상황.jpg')
display(img3)

text3 = pytesseract.image_to_string(img3, lang='kor+eng')
print(text3)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=680x386>
# 원무창구위치 창구
#
# [대 외래센터 1층                 접수ㆍ수납
# B 외래센터 1층                 신환자접수
# [대 외래센터 2층                 접수ㆍ수납
# [대 외래센터 4층                 접수ㆍ수납
# [쾌 외래센터 5층                 접수ㆍ수납
# [대 외래센터 1층                  검사예약
#
# B 의래센터 1층                   제증명

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

img4 = Image.open('대기자 명단.png')
display(img4)

text4 = pytesseract.image_to_string(img4, lang='kor+eng')
print(text4)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=289x664>
# 800 . 80 - 80 |. 80 80 - 80 CRO
#
# 2 작ㅇ00 ㄴㅇ

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

img5 = Image.open('혼잡도.png')
display(img5)

text5 = pytesseract.image_to_string(img5, lang='kor')
print(text5)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=296x664>

# %%
img5 = Image.open('원무창구.png')
display(img5)

text5 = pytesseract.image_to_string(img5, lang='kor+eng')
print(text5)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=535x662>
# 원무 창구 위치
#
# © 외래센터 1층
# © 외래센터 1층
# [쾌 외래센터 2층
# [케 외래센터 4층
# ©} 외래센터 5층
# © 외래센터 1층
# [쾌 외래센터 1층

# %%
img6 = Image.open('창구.png')
display(img6)

text6 = pytesseract.image_to_string(img6, lang='kor+eng')
print(text6)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=145x475>
# 제증명
